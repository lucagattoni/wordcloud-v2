# %% [markdown]
# <img class="k-inline-icon" style="max-width:26px; float:left;" src="https://colab.research.google.com/img/colab_favicon.ico">&nbsp;&nbsp;<a target="_blank" href="https://colab.research.google.com/drive/15BlurWaXf2L9Qmo3kJZBBM4cdsfBroCQ"><strong>View in Colab</strong></a>

# %%
# !pip install --upgrade wordcloud
# !pip install --upgrade wikipedia
# Out:
# Requirement already satisfied: wordcloud in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from wordcloud) (1.19.5)
# Requirement already satisfied: pillow in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.28.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)
# Requirement already satisfied: wikipedia in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from wikipedia) (4.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from wikipedia) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.10)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from beautifulsoup4->wikipedia) (2.3.1)

# %%
import wikipedia
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
# parameters

debug = True

max_words = 100
min_word_length = 6
collocation_threshold = 30  # default value. Bigrams must have a Dunning likelihood collocation score greater than this parameter to be counted as bigrams.
background_color = 'white'

page = "Compouter security"
additional_stopwords = {'US', 'act' 'simple', 'exist', 'may', 'reducing', 'often', 'started', 'general', 'common', 'way', 'provide', 'including', 'air', 'known', 'ensure', 'u', 'mean', 'well', 'create', 'created', 'non', 'typically', 'within', 'range', 'made', 'need', 'due', 'even', 'post', 'considered', 'using', 'making', 'part', 'different', 'possible', 'designed', 'called', 'using', 'able', 'many', 'another', 'based', 'even', 'will', 'two', 'use', 'make', 'used', 'first', 'new'}

# %%
all_stopwords = additional_stopwords.union(STOPWORDS)

if debug:
    print(all_stopwords)
# Out:
# {'of', "you'll", "hadn't", "we'd", 'below', 'what', "you're", 'his', 'or', "doesn't", 'yours', 'had', "she's", 'was', 'during', 'he', 'designed', 'common', 'will', 'once', 'yourselves', 'its', 'about', 'be', 'out', 'when', 'she', 'does', 'including', 'only', 'her', 'into', 'well', 'our', "wasn't", 'since', 'ought', 'than', 'in', 'me', 'because', "he's", 'other', 'shall', "she'd", 'way', 'otherwise', 'why', 'who', 'most', "you'd", 'able', 'could', 'so', 'own', 'a', "we've", "he'd", 'while', "they're", 'else', 'therefore', 'under', "i'm", "shan't", "they'll", 'and', "weren't", 'where', 'being', 'k', "who's", 'used', 'like', 'them', 'over', "won't", 'you', 'cannot', 'using', 'range', 'each', "there's", 'whom', 'reducing', 'called', 'with', 'until', "aren't", "what's", 'doing', "let's", 'create', 'general', 'which', 'from', 'two', 'considered', 'too', 'not', 'itself', 'if', 'your', 'himself', "they've", 'ourselves', 'com', 'these', 'made', 'those', 'no', 'herself', "we'll", 'provide', 'this', 'both', 'hence', "i'd", 'ever', "how's", 'just', 'they', 'were', 'against', 'started', 'the', "why's", 'use', 'at', 'may', 'based', 'between', 'yourself', 'any', 'same', 'but', 'www', "they'd", "where's", 'air', 'making', 'after', 'nor', 'few', 'such', 'have', 'more', 'through', 'am', 'by', 'off', 'typically', 'did', 'that', 'often', 'non', 'known', 'new', 'how', "haven't", "it's", 'my', 'ours', 'been', 'even', 'make', 'i', 'US', 'here', 'ensure', 'some', 'on', "shouldn't", 'different', 'is', "you've", "she'll", 'also', 'then', "don't", 'their', 'first', "can't", 'part', 'should', 'again', 'many', 'actsimple', 'can', 'get', 'up', "he'll", 'down', 'for', 'it', "here's", 'created', 'to', 'due', "when's", 'r', "we're", "mustn't", 'theirs', 'post', 'within', 'an', 'would', 'before', 'exist', 'are', 'themselves', 'all', 'hers', 'mean', "isn't", 'http', "wouldn't", 'we', "i've", 'having', "i'll", 'need', 'possible', 'another', "couldn't", 'him', 'however', "didn't", 'there', 'has', 'further', "that's", 'as', 'do', "hasn't", 'myself', 'u', 'very', 'above'}

# %%
article = wikipedia.page(page)
if debug:
    print (article.url)
# Out:
# https://en.wikipedia.org/wiki/Computer_security

# %%
wc = WordCloud(width=1000, height=1000, min_word_length=min_word_length, max_words=max_words, collocation_threshold=collocation_threshold, background_color=background_color, stopwords=all_stopwords)
wc_img = wc.generate(article.content)

# %%
plt.figure(figsize=(18, 18))
plt.axis("off")
plt.imshow(wc_img);
